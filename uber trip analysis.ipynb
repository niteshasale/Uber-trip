# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv('uber-raw-data-apr14.csv')

# %%
data.head()
# Out:
#           Date/Time      Lat      Lon    Base
# 0  4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1  4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2  4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3  4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4  4/1/2014 0:33:00  40.7594 -73.9722  B02512

# %%
data.shape
# Out:
# (564516, 4)

# %% [markdown]
# ### convert datetime format properly

# %%
data['Date/Time']=pd.to_datetime(data['Date/Time'])

# %%
data.dtypes
# Out:
# Date/Time    datetime64[ns]
# Lat                 float64
# Lon                 float64
# Base                 object
# dtype: object

# %%
data.head()
# Out:
#             Date/Time      Lat      Lon    Base
# 0 2014-04-01 00:11:00  40.7690 -73.9549  B02512
# 1 2014-04-01 00:17:00  40.7267 -74.0345  B02512
# 2 2014-04-01 00:21:00  40.7316 -73.9873  B02512
# 3 2014-04-01 00:28:00  40.7588 -73.9776  B02512
# 4 2014-04-01 00:33:00  40.7594 -73.9722  B02512

# %% [markdown]
# ### createa a some new columns according to the datetime

# %%
def get_dom(x):
    return x.day
data['dom'] = data['Date/Time'].apply(lambda x:get_dom(x))

# %%
data.head()
# Out:
#             Date/Time      Lat      Lon    Base  dom
# 0 2014-04-01 00:11:00  40.7690 -73.9549  B02512    1
# 1 2014-04-01 00:17:00  40.7267 -74.0345  B02512    1
# 2 2014-04-01 00:21:00  40.7316 -73.9873  B02512    1
# 3 2014-04-01 00:28:00  40.7588 -73.9776  B02512    1
# 4 2014-04-01 00:33:00  40.7594 -73.9722  B02512    1

# %%
def get_dom(x):
    return x.day
data['dom'] = data['Date/Time'].apply(lambda x: get_dom(x))

# %%
data.head()
# Out:
#             Date/Time      Lat      Lon    Base  dom
# 0 2014-04-01 00:11:00  40.7690 -73.9549  B02512    1
# 1 2014-04-01 00:17:00  40.7267 -74.0345  B02512    1
# 2 2014-04-01 00:21:00  40.7316 -73.9873  B02512    1
# 3 2014-04-01 00:28:00  40.7588 -73.9776  B02512    1
# 4 2014-04-01 00:33:00  40.7594 -73.9722  B02512    1

# %%
def get_weekday(x):
    return x.weekday()
data['weekday'] = data['Date/Time'].apply(lambda x: get_weekday(x))

# %%
def get_hour(x):
    return x.hour
data['hour'] = data['Date/Time'].apply(lambda x: get_hour(x))

# %%
data.tail()
# Out:
#                  Date/Time      Lat      Lon    Base  dom  weekday  hour
# 564511 2014-04-30 23:22:00  40.7640 -73.9744  B02764   30        2    23
# 564512 2014-04-30 23:26:00  40.7629 -73.9672  B02764   30        2    23
# 564513 2014-04-30 23:31:00  40.7443 -73.9889  B02764   30        2    23
# 564514 2014-04-30 23:32:00  40.6756 -73.9405  B02764   30        2    23
# 564515 2014-04-30 23:48:00  40.6880 -73.9608  B02764   30        2    23

# %%
hist(data.dom,bins=30,rwidth=.8)
plt.xlabel('Date of the Month')
plt.ylabel('Frequency')
plt.show()
